# %%
function = piecewise([((-pi, 0), 0), ((0, pi), sin(x))])

# %%
plot(function, (-pi, pi), color='#ff00ff')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
s4 = function.fourier_series_partial_sum(4)

# %%
plot(s4, (x, -pi, pi), color='#ff00ff')
# Out:
# Graphics object consisting of 1 graphics primitive
